# %%
import gmaps
import gmaps.datasets

gmaps.configure(api_key="AIzaSyDR3xtBsa2ICsh3dQVuVMBM9IUAiqWuino")

# %% [markdown]
# To use gmaps read `README.md`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
FILENAME_DATASET = 'Dataset/baltimore_crimes.csv'

df = pd.read_csv(FILENAME_DATASET, sep=',', index_col=False)
locations = df['Location 1'].values
a = []
b = []
coord = []
df.head()
# Out:
#     CrimeDate CrimeTime CrimeCode              Location        Description  \
# 0  09/01/2015  23:58:00        4C         600 S PACA ST       AGG. ASSAULT
# 1  09/01/2015  23:36:00        6J        1000 EVANS WAY            LARCENY
# 2  09/01/2015  23:30:00        4B          300 W CAMDEN       AGG. ASSAULT
# 3  09/01/2015  23:30:00        6D          1100 RACE ST  LARCENY FROM AUTO
# 4  09/01/2015  22:25:00        4E  1000 WASHINGTON BLVD     COMMON ASSAULT
#
#   Weapon   Post      District               Neighborhood  \
# 0  OTHER  941.0      SOUTHERN          Ridgely's Delight
# 1    NaN  433.0  NORTHEASTERN          Armistead Gardens
# 2  KNIFE  941.0       CENTRAL               Stadium Area
# 3    NaN  942.0      SOUTHERN           Sharp-Leadenhall
# 4    NaN  932.0      SOUTHERN  Washington Village/Pigtow
#
#                             Location 1  Total Incidents
# 0  (39.283010000000, -76.624750000000)                1
# 1  (39.304860000000, -76.545180000000)                1
# ...

# %% [markdown]
# # Question 1

# %%
# Ques 1
_ = df['District'].value_counts(ascending=True).plot(kind='barh', title='Crime frequency of Districts')

# %% [markdown]
# `SOUTHEASTERN DISTRICT` has the highest number of crimes.
#
# `NORTHEASTERN DISTRCT` has the least number of crimes.

# %% [markdown]
# # Question 2

# %%
# Ques 2
for i in range(len(locations)):
#     print (locations[i])
    locations[i] = locations[i].strip('(')
    locations[i] = locations[i].strip(')')
    locations[i] = locations[i].split(',')
    a.append(float(locations[i][0]))
    b.append(float(locations[i][1]))
    temp = (a[i],b[i])
    coord.append(temp)

# %%
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(coord))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Heatmap of the crimes committed across the city

# %% [markdown]
# <img src="ques2_map.png">

# %% [markdown]
# No, the crimes are not evenly divided across the city. The red regions are regions with highest number of crimes reported.

# %% [markdown]
# # Question 3

# %%
day = []
date = df['CrimeDate'].values
dayArray = ['Monday','Tuesday','Wednsday','Thursday','Friday','Saturday','Sunday']
from dateutil.parser import parse
import datetime as dt
for i in range(len(date)):
    temp = dt.datetime.strptime(date[i], '%m/%d/%Y').weekday()
    day.append(dayArray[temp])

# %%
df['Day'] = day
_ = df['Day'].value_counts(ascending=True).plot(kind='barh', title='Frequency of crime vs day of week')

# %% [markdown]
# Most number of crimes happen on `Tuesday`

# %%
for index in range(len(df['CrimeTime'])):
    df['CrimeTime'][index] = df['CrimeTime'][index][0:2]
# Out:
# /home/killinsteak/.venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
_ = df['CrimeTime'].value_counts(ascending=True).plot(kind='barh', title='Frequency of Crime vs Time of day(in hrs)')

# %% [markdown]
# Most number of crimes happen between `1800 - 1859`

# %%
# df1 = df[df.CrimeTime == '20' or df.CrimeTime == '21' or df.CrimeTime == '22' or df.CrimeTime == '23']
# fig, ax = plt.subplots()
plt.figure(figsize = (20, 20))
for key, grp in df.groupby(['Description']):
    timeFreq = {}
    for index, rows in grp.iterrows():
        if int(rows['CrimeTime']) in timeFreq.keys():
            timeFreq[int(rows['CrimeTime'])] += 1
        else:
            timeFreq[int(rows['CrimeTime'])] = 1
    lists = sorted(timeFreq.items())
    x, y = zip(*lists) # unpack a list of pairs into two tuples
    plt.plot(x, y, label = key)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    
plt.xticks(np.arange(0, 23+1, 1.0))    
plt.xlabel('Time in hrs')
plt.ylabel('Frequency')
plt.title('Frequency of crimes vs Time of Day')
plt.show()
# a.head()
# plt.legend(loc='best')
# plt.show()

# %% [markdown]
# Considering Larceny and Larceny from Auto as a single type of crime we can say Larceny is most likely to happen between 2000 Hrs and 2359 Hrs.
#
# Else Larceny from Auto is most likely to happen between 2000 Hrs and 2359 Hrs.

# %% [markdown]
# # Question 4

# %%
_ = df['Description'].value_counts(ascending=True).plot(kind='barh', title='Crime frequency of Districts')

# %% [markdown]
# Larceny is the most common crime.

# %%
df1 = df[df.Description == 'LARCENY']
_ = df1['CrimeTime'].value_counts(ascending=True).plot(kind='barh', title='Frequency of Larceny vs Time of day(in hrs)')

# %% [markdown]
# Larceny is most likely to happen between 1600 Hrs to 1659 Hrs.

# %%
# locations = df1['Location 1'].values
a = []
b = []
i = 0
coord = []
for index,row in df1.iterrows():
#     print (locations[i])
    a.append(float(df1['Location 1'][index][0]))
    b.append(float(df1['Location 1'][index][1]))
#     b.append(float(locations[i][1]))
    temp = (a[i],b[i])
    i += 1
    coord.append(temp)

fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(coord))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Heatmap of Larceny across the city

# %% [markdown]
# <img src="ques4_map.png">

# %% [markdown]
# No, the crime is not evenly spread out.
#
# Some regions have high incident of Larceny, while others are free from Larceny.
